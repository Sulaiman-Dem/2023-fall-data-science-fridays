# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3]
y = [1, 6, 8]
z = [1, 9, 10]

plt.plot(x, y)
plt.plot(x, z)

plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y and z")

plt.legend(["This is y", "This is z"])

# %%
import os

path = os.getcwd()

print(path)
# Out:
# c:\Users\winge\OneDrive\Desktop\(C)Coding\CUNY Tech Prep\Fall 2023\2023-fall-data-science-fridays\Pre-Work Homework\H-W2 - Data Visualization, EDA, and Github

# %%
sample_data = pd.read_csv("/data/sample_data.csv")

sample_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sample_data = pd.read_csv("/data/sample_data.csv")
#       3 sample_data
#
# File c:\Users\winge\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\winge\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
type(sample_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 type(sample_data)
#
# NameError: name 'sample_data' is not defined

# %%
sample_data.columns_c.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sample_data.columns_c.iloc[0]
#
# NameError: name 'sample_data' is not defined

# %%
# iloc allows for you to get a specific index

# %%
plt.plot(sample_data.column_a, sample_data.column_b, 'o')
plt.plot(sample_data.column_c, sample_data.column_a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.plot(sample_data.column_a, sample_data.column_b, 'o')
#       2 plt.plot(sample_data.column_c, sample_data.column_a)
#
# NameError: name 'plt' is not defined

# %%
pd.read_('countries.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.read_('countries.csv')
#
# File c:\Users\winge\anaconda3\Lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_'

# %%
# compare US and China growth

# %%
us = data[data.country == 'United States']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 us = data[data.country == 'United States']
#
# NameError: name 'data' is not defined

# %%
china = data[data.country == 'China']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 china = data[data.country == 'China']
#
# NameError: name 'data' is not defined

# %%
plt.plot(us.year, us.population / 10**6)
plt.plot(china.year, china.population / 10**6)
plt.legend(['United States', 'China'])
plt.xlabel('year')
plt.ylabel('population')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.plot(us.year,us.population / 10**6)
#       2 plt.plot(china.year,china.population / 10**6)
#       3 plt.legend(['United States', 'China'])
#
# NameError: name 'us' is not defined

# %%
us.population
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 us.population
#
# NameError: name 'us' is not defined

# %%
us.population.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 us.population.iloc[0]
#
# NameError: name 'us' is not defined

# %%
us.population / us.population.iloc[0] * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 us.population / us.population.iloc[0] * 100
#
# NameError: name 'us' is not defined

# %%
plt.plot(us.year, us.population / us.population.iloc[0] * 100)
plt.plot(china.year, china.population / us.population.iloc[0] * 100)
plt.legend(['United States', 'China'])
plt.xlabel('year')
plt.ylabel('population growth (first year = 100)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plt.plot(us.year,us.population / us.population.iloc[0] * 100)
#       2 plt.plot(china.year,china.population / us.population.iloc[0] * 100)
#       3 plt.legend(['United States', 'China'])
#
# NameError: name 'us' is not defined
